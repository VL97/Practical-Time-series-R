# %% [markdown]
# (1,0,1) means <br>autoregressive order (1), the order of any differencing (0), and then the order of the moving average part (1).<br>
# <center><h2> 𝑋<sub>t</sub> = 0.7𝑋<sub>t-1</sub> + 𝑍<sub>t</sub> + 0.2𝑍<sub>t-1</sub>  </center></h2>

# %%
set.seed(500) 
data = arima.sim( list(order = c(1,0,1), ar =.7, ma=.2), n = 1000000)
par(mfcol = c(3,1 ))
plot(data, main="ARMA(1,1) Time Series: phi1=.7, theta1=.2", xlim=c(0,400)) #first terms
acf(data, main="Autocorrelation of ARMA(1,1), phi1=.7, theta1=.2")
acf(data, type="partial", main="Partial Autocorrelation of ARMA(1,1), phi1=.7, theta1=.2")
# Out:
# Plot with title "Partial Autocorrelation of ARMA(1,1), phi1=.7, theta1=.2"

# %% [markdown]
# The ACF lines up with our formula in ARMA pdf:

# %%
(acf(data, main="Autocorrelation of ARMA(1,1), phi1=.7, theta1=.2"))[1:4]
# Out:
# Autocorrelations of series 'data', by lag
#
#     1     2     3     4
# 0.777 0.544 0.380 0.266
# Plot with title "Autocorrelation of ARMA(1,1), phi1=.7, theta1=.2"
