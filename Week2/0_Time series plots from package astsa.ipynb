# %%
data(package='astsa')

# %%
data(jj, package='astsa')

# %%
jj
# Out:
# ERROR while rich displaying an object: Error in repr_matrix_generic(obj, "\n%s%s\n", sprintf("|%%s\n|%s|\n", : formal argument "cols" matched by multiple actual arguments
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
# ...

# %% [markdown]
# trend is seen with higher volatility at later times:

# %%
plot(jj, type='o', main='Johnson and Johnson quarterly earning per share', ylab='Earnings', xlab='Years')
# Out:
# Plot with title "Johnson and Johnson quarterly earning per share"

# %%
data(flu, package='astsa')

# %%
flu
# Out:
# ERROR while rich displaying an object: Error in repr_matrix_generic(obj, "\n%s%s\n", sprintf("|%%s\n|%s|\n", : formal argument "cols" matched by multiple actual arguments
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
# ...

# %% [markdown]
# seasonality is seen with maybe decreasing fatalities trend?:

# %%
plot(flu, type='o', main='Monthly pneumonia deaths in US', ylab='No of deaths per 10,000 people', xlab='Months')
# Out:
# Plot with title "Monthly pneumonia deaths in US"

# %%
data(globtemp, package='astsa')

# %% [markdown]
# We can see some sort of both seasonality and trend:

# %%
plot(globtemp, type='o', main='Global mean temperature deviations:base period 1951-1980 avg', ylab='Temp deviations', xlab='Years')
# Out:
# Plot with title "Global mean temperature deviations:base period 1951-1980 avg"

# %%
data(star, package='astsa')

# %% [markdown]
# We can definitely see seasonality here:

# %%
plot(star, main='Magnitude of a single star taken for 600 consecutive days', ylab='Magnitude', xlab='days')
# Out:
# Plot with title "Magnitude of a single star taken for 600 consecutive days"
